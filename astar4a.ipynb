# %%
import numpy as np
import time
from heapq import *
import matplotlib.pyplot as plt
# cost matrix as a numpy array
start_time = time.time()
cost = np.random.seed(6)
cost = np.random.randint(10, size=(20, 20),)

#print(cost)
#imgplot=plt.imshow(cost)
#print test of cost matrix and specific index in numpy array
#print(cost)
#print(cost[9,6])
# create the problem grid a rows and b columns
searchArea = [] 
def createGrid(a,b):
    for x in range(a):
        for y in range(b):
            searchArea.append([x, y])
#print test of grid        
#print(grid)

# expansion function to find adjacent neighbors of current node, can move vertical and horizontal so four directions are needed
#must also only move within the grid
def expand(node): 
    adjacentNodes = [[1, 0], [0, 1], [-1, 0], [0, -1]]
    result = []
    for adjacent in adjacentNodes:
        neighbor = [node[0] + adjacent[0], node[1] + adjacent[1]]
        if neighbor in grid:
            result.append(neighbor)
    return result
def heuristic(first, second): # first = current node, second = goal node first and second are two index tuples
    return abs(second[0] - first[0]) + abs(second[1] - first[1])
#def evaluation(neighborNode, end):
def evaluation(eNode):
    #create a copy of enode, pull values out of copy and assign to valiables i, j
    #pass i, j to slice cost numpy array for cost value of node
    print()
    print("function call to cost evaluation:")
    index = eNode[:]
    print("index: ",  index)
    #print(index)
    #cast the tuple index into a list so that the values can be interated and popped
    index = list(index)
    print("index after cast: ", index)
    while len(index)>0:
        indexI = index.pop(0)
        i = indexI
        indexJ = index.pop(0)
        j = indexJ
    print("Obtain cost of node: [", i,j, "] from numpy array cost matrix" )
    #print(i,j)
    print()
    #hValue = heuristic(eNode, end)
    # cannot use cost() must use cost[], using () makes python interpret as a function call
    
    gVal = cost[i,j] #+ parentNodeG
    #fValue = hValue + gValue
    
    #print("hValue:")
    #print(hValue)
    print()
    print("gVal: ", + gVal)
    
    #print()
    #print("fValue")
    #print(fValue)
    #print()
    #return fValue
    return gVal

    

# astar function,  
def astarPath(grid, start, goal):
    #declare an open list that will be turned into a heap for popping the smallest f Value
    openList = []
    #declare a dictionary to hold a node's parent
    parentNode = {}
    #sets are quicker than lists, declare a set for the closed nodes
    closedNodes = set()
    gCheck = 1
    #frontier = []
    #seenList = []
    #declare a dictionary to hold the g values
    gValue = {start:0}
    #declare a dictionary to hold the f values
    
    fValue = {start:heuristic(start,goal)}
    
    #values for expnsion to find adjancent nodes to current node
    adjacentNodes = [[0, 1], [1, 0], [-1, 0], [0, -1]]
    #variables for iteration of main for loop
    i=1
    r = 1
    # turn the openList into a heap and place the starting node and its fValue, as a tuple, on the heap
    heappush(openList, (fValue[start], start))
    while openList:
        #set current node by:
        #heappop the node from the openList heap, use [1] so that currentNode will only take the node
        #not the node and its fValue
        
        currentNode = heappop(openList)[1]
        print("Current Node: ", currentNode)
        #print()
        
        #goal check
        if currentNode == goal:
            print("Goal has been reached")
            nodePath = []
            while currentNode in parentNode:
                nVal = evaluation(currentNode)
                print(currentNode," g is cost of current node: ",nVal,", + cost of parent node,total is: " ,gValue[currentNode]," h cost is: ",heuristic(currentNode, goal), " and f cost is: ",fValue[currentNode]  )
                nodePath.append(currentNode)
                currentNode = parentNode[currentNode]
            print("Path to goal is: ", nodePath[::-1])    
            return nodePath[::-1]
            #print("Path to goal is: ", nodePath)
             #while len(nodePath)>0:
                    #node = nodePath.pop(0)
                    
                    
        else:
            print("Unsuccessful goal check number: ", gCheck)
            gCheck += 1
            
        #add the current node to the closed set    
            closedNodes.add(currentNode)
            print("Closed Nodes: ", closedNodes)
        # declare for loop to find adjacent nodes to current node
        # a, b are [0] and [1] in the 4 directions of movement
        for a, b in adjacentNodes:
            print()
            print("Main for-loop iteration: ", i)
            print("The currentNode is: ", currentNode)
            print("[0] value in adjacentNode list: ", a)
           
            print("[1] value in adjacentnode list :" , b)
            
            
            
            
            
           
            #declare variable checkNode to hold newly created node to see if it's on the array
            checkNode = currentNode[0] + a, currentNode[1] + b
            
            print("This is checkNode: ",checkNode, "in iteration: ", r)
           
            i+=1
            r+=1
            if 0 <= checkNode[0]:
                print("Check 1 passed")
                if 9 >= checkNode[0]:
                    print("Check 2 passed")
                    if 0 <= checkNode[1]:
                        print("Check 3 passed")
                   
                        if 9 >=checkNode[1]:
                            print("checkNode: ", checkNode, "is on the array")
                            #print("checkNode:", checkNode)
                            neighborNode = checkNode
                            print("neighborNode", neighborNode, "has taken the value of checkNode")
                            gVal = evaluation(neighborNode)
                            print("g cost of  neighborNode: ", neighborNode, "without adding parent cost is: ", gVal)
                            tempGValue = gValue[currentNode] + gVal
                            print("g cost of parent node: ", currentNode, "is: ",gValue[currentNode] )
                            print("g cost of neighborNode: ", neighborNode, "plus its parentNode's: ", currentNode, "g cost is: ", tempGValue)
                            # if the neighborNode is in the closed set and its g value is greater
                            #than the same node in the closedset do not put it in the closedset and keep going
                            if neighborNode in closedNodes and tempGValue >= gValue.get(neighborNode, 0):
                                print(neighborNode, 'not pushed')
                                continue
                            # check to see if the neighborNode already has a value listed in the g value dict
                            # if it doesn't reurn zero, if the new temp g value is less than the existing value 
                            #or if if it isn't first on the openList heap then perform the following:
                            if tempGValue < gValue.get(neighborNode, 0) or neighborNode not in [nNode[1] for nNode in openList]:
                                parentNode[neighborNode] = currentNode
                                gValue[neighborNode] = tempGValue
                                fValue[neighborNode] = tempGValue + heuristic(neighborNode, goal)
                                h =  heuristic(neighborNode, goal)
                                heappush(openList, (fValue[neighborNode], neighborNode))
                                print(neighborNode, " added to open list")
                                print("h of neighborNode: ", neighborNode, "is: ",h )
                                print("f cost of neighborNode: ", neighborNode, "is: ",fValue[neighborNode] )
                        else:
                            print(checkNode, ":not on array")
                            continue 
                    
                    
                    else:
                        print(checkNode, ":not on array")
                        continue       
                else:
                    print(checkNode, ":not on array")
                    continue         
                                
            else:
                print(checkNode, ":not on array")
                continue                
                        
                        
       # print("this is the nNode: ",  neighborNode)
        
        
       
    
print("Please create the grid by typing: grid = createGrid() with two parameters that will determine the size of the grid")
print("For example: grid = createGrid(20,20) will create a 20 X 20 grid space")
print("After creating the grid type: astarPath(grid, start, end)")
print(" start and end are x,y coordinates of the start and end points of the path")
print("For example: astarPath(grid, (0,0), (8,2)), please ensure the points are contained within the grid space")
#grid = createGrid(20,20)    
#astarPath(grid, (0,0), (8,2))    
#print ("Astar took", time.time() - start_time, "to run")
# Out:
# Please create the grid by typing: grid = createGrid() with two parameters that will determine the size of the grid
# For example: grid = createGrid(20,20) will create a 20 X 20 grid space
# After creating the grid type: astarPath(grid, start, end)
#  start and end are x,y coordinates of the start and end points of the path
# For example: astarPath(grid, (0,0), (8,2)), please ensure the points are contained within the grid space

# %%
grid=createGrid(10,10)

# %%
astarPath(grid, (0,0), (8,2))
# Out:
# Current Node:  (0, 0)
# Unsuccessful goal check number:  1
# Closed Nodes:  {(0, 0)}
#
# Main for-loop iteration:  1
# The currentNode is:  (0, 0)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (0, 1) in iteration:  1
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 1) is on the array
# neighborNode (0, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 1)
# index after cast:  [0, 1]
# Obtain cost of node: [ 0 1 ] from numpy array cost matrix
#
#
# gVal:  3
# g cost of  neighborNode:  (0, 1) without adding parent cost is:  3
# g cost of parent node:  (0, 0) is:  0
# g cost of neighborNode:  (0, 1) plus its parentNode's:  (0, 0) g cost is:  3
# (0, 1)  added to open list
# h of neighborNode:  (0, 1) is:  9
# f cost of neighborNode:  (0, 1) is:  12
#
# Main for-loop iteration:  2
# The currentNode is:  (0, 0)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (1, 0) in iteration:  2
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 0) is on the array
# neighborNode (1, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 0)
# index after cast:  [1, 0]
# Obtain cost of node: [ 1 0 ] from numpy array cost matrix
#
#
# gVal:  1
# g cost of  neighborNode:  (1, 0) without adding parent cost is:  1
# g cost of parent node:  (0, 0) is:  0
# g cost of neighborNode:  (1, 0) plus its parentNode's:  (0, 0) g cost is:  1
# (1, 0)  added to open list
# h of neighborNode:  (1, 0) is:  9
# f cost of neighborNode:  (1, 0) is:  10
#
# Main for-loop iteration:  3
# The currentNode is:  (0, 0)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (-1, 0) in iteration:  3
# (-1, 0) :not on array
#
# Main for-loop iteration:  4
# The currentNode is:  (0, 0)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (0, -1) in iteration:  4
# Check 1 passed
# Check 2 passed
# (0, -1) :not on array
# Current Node:  (1, 0)
# Unsuccessful goal check number:  2
# Closed Nodes:  {(1, 0), (0, 0)}
#
# Main for-loop iteration:  5
# The currentNode is:  (1, 0)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (1, 1) in iteration:  5
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 1) is on the array
# neighborNode (1, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 1)
# index after cast:  [1, 1]
# Obtain cost of node: [ 1 1 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (1, 1) without adding parent cost is:  4
# g cost of parent node:  (1, 0) is:  1
# g cost of neighborNode:  (1, 1) plus its parentNode's:  (1, 0) g cost is:  5
# (1, 1)  added to open list
# h of neighborNode:  (1, 1) is:  8
# f cost of neighborNode:  (1, 1) is:  13
#
# Main for-loop iteration:  6
# The currentNode is:  (1, 0)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 0) in iteration:  6
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 0) is on the array
# neighborNode (2, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 0)
# index after cast:  [2, 0]
# Obtain cost of node: [ 2 0 ] from numpy array cost matrix
#
#
# gVal:  6
# g cost of  neighborNode:  (2, 0) without adding parent cost is:  6
# g cost of parent node:  (1, 0) is:  1
# g cost of neighborNode:  (2, 0) plus its parentNode's:  (1, 0) g cost is:  7
# (2, 0)  added to open list
# h of neighborNode:  (2, 0) is:  8
# f cost of neighborNode:  (2, 0) is:  15
#
# Main for-loop iteration:  7
# The currentNode is:  (1, 0)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (0, 0) in iteration:  7
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 0) is on the array
# neighborNode (0, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 0)
# index after cast:  [0, 0]
# Obtain cost of node: [ 0 0 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (0, 0) without adding parent cost is:  9
# g cost of parent node:  (1, 0) is:  1
# g cost of neighborNode:  (0, 0) plus its parentNode's:  (1, 0) g cost is:  10
# (0, 0) not pushed
#
# Main for-loop iteration:  8
# The currentNode is:  (1, 0)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (1, -1) in iteration:  8
# Check 1 passed
# Check 2 passed
# (1, -1) :not on array
# Current Node:  (0, 1)
# Unsuccessful goal check number:  3
# Closed Nodes:  {(0, 1), (1, 0), (0, 0)}
#
# Main for-loop iteration:  9
# The currentNode is:  (0, 1)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (0, 2) in iteration:  9
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 2) is on the array
# neighborNode (0, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 2)
# index after cast:  [0, 2]
# Obtain cost of node: [ 0 2 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (0, 2) without adding parent cost is:  4
# g cost of parent node:  (0, 1) is:  3
# g cost of neighborNode:  (0, 2) plus its parentNode's:  (0, 1) g cost is:  7
# (0, 2)  added to open list
# h of neighborNode:  (0, 2) is:  8
# f cost of neighborNode:  (0, 2) is:  15
#
# Main for-loop iteration:  10
# The currentNode is:  (0, 1)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (1, 1) in iteration:  10
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 1) is on the array
# neighborNode (1, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 1)
# index after cast:  [1, 1]
# Obtain cost of node: [ 1 1 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (1, 1) without adding parent cost is:  4
# g cost of parent node:  (0, 1) is:  3
# g cost of neighborNode:  (1, 1) plus its parentNode's:  (0, 1) g cost is:  7
#
# Main for-loop iteration:  11
# The currentNode is:  (0, 1)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (-1, 1) in iteration:  11
# (-1, 1) :not on array
#
# Main for-loop iteration:  12
# The currentNode is:  (0, 1)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (0, 0) in iteration:  12
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 0) is on the array
# neighborNode (0, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 0)
# index after cast:  [0, 0]
# Obtain cost of node: [ 0 0 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (0, 0) without adding parent cost is:  9
# g cost of parent node:  (0, 1) is:  3
# g cost of neighborNode:  (0, 0) plus its parentNode's:  (0, 1) g cost is:  12
# (0, 0) not pushed
# Current Node:  (1, 1)
# Unsuccessful goal check number:  4
# Closed Nodes:  {(0, 1), (1, 0), (0, 0), (1, 1)}
#
# Main for-loop iteration:  13
# The currentNode is:  (1, 1)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (1, 2) in iteration:  13
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 2) is on the array
# neighborNode (1, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 2)
# index after cast:  [1, 2]
# Obtain cost of node: [ 1 2 ] from numpy array cost matrix
#
#
# gVal:  5
# g cost of  neighborNode:  (1, 2) without adding parent cost is:  5
# g cost of parent node:  (1, 1) is:  5
# g cost of neighborNode:  (1, 2) plus its parentNode's:  (1, 1) g cost is:  10
# (1, 2)  added to open list
# h of neighborNode:  (1, 2) is:  7
# f cost of neighborNode:  (1, 2) is:  17
#
# Main for-loop iteration:  14
# The currentNode is:  (1, 1)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 1) in iteration:  14
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 1) is on the array
# neighborNode (2, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 1)
# index after cast:  [2, 1]
# Obtain cost of node: [ 2 1 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (2, 1) without adding parent cost is:  9
# g cost of parent node:  (1, 1) is:  5
# g cost of neighborNode:  (2, 1) plus its parentNode's:  (1, 1) g cost is:  14
# (2, 1)  added to open list
# h of neighborNode:  (2, 1) is:  7
# f cost of neighborNode:  (2, 1) is:  21
#
# Main for-loop iteration:  15
# The currentNode is:  (1, 1)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (0, 1) in iteration:  15
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 1) is on the array
# neighborNode (0, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 1)
# index after cast:  [0, 1]
# Obtain cost of node: [ 0 1 ] from numpy array cost matrix
#
#
# gVal:  3
# g cost of  neighborNode:  (0, 1) without adding parent cost is:  3
# g cost of parent node:  (1, 1) is:  5
# g cost of neighborNode:  (0, 1) plus its parentNode's:  (1, 1) g cost is:  8
# (0, 1) not pushed
#
# Main for-loop iteration:  16
# The currentNode is:  (1, 1)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (1, 0) in iteration:  16
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 0) is on the array
# neighborNode (1, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 0)
# index after cast:  [1, 0]
# Obtain cost of node: [ 1 0 ] from numpy array cost matrix
#
#
# gVal:  1
# g cost of  neighborNode:  (1, 0) without adding parent cost is:  1
# g cost of parent node:  (1, 1) is:  5
# g cost of neighborNode:  (1, 0) plus its parentNode's:  (1, 1) g cost is:  6
# (1, 0) not pushed
# Current Node:  (0, 2)
# Unsuccessful goal check number:  5
# Closed Nodes:  {(0, 1), (0, 0), (1, 1), (1, 0), (0, 2)}
#
# Main for-loop iteration:  17
# The currentNode is:  (0, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (0, 3) in iteration:  17
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 3) is on the array
# neighborNode (0, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 3)
# index after cast:  [0, 3]
# Obtain cost of node: [ 0 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (0, 3) without adding parent cost is:  0
# g cost of parent node:  (0, 2) is:  7
# g cost of neighborNode:  (0, 3) plus its parentNode's:  (0, 2) g cost is:  7
# (0, 3)  added to open list
# h of neighborNode:  (0, 3) is:  9
# f cost of neighborNode:  (0, 3) is:  16
#
# Main for-loop iteration:  18
# The currentNode is:  (0, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (1, 2) in iteration:  18
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 2) is on the array
# neighborNode (1, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 2)
# index after cast:  [1, 2]
# Obtain cost of node: [ 1 2 ] from numpy array cost matrix
#
#
# gVal:  5
# g cost of  neighborNode:  (1, 2) without adding parent cost is:  5
# g cost of parent node:  (0, 2) is:  7
# g cost of neighborNode:  (1, 2) plus its parentNode's:  (0, 2) g cost is:  12
#
# Main for-loop iteration:  19
# The currentNode is:  (0, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (-1, 2) in iteration:  19
# (-1, 2) :not on array
#
# Main for-loop iteration:  20
# The currentNode is:  (0, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (0, 1) in iteration:  20
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 1) is on the array
# neighborNode (0, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 1)
# index after cast:  [0, 1]
# Obtain cost of node: [ 0 1 ] from numpy array cost matrix
#
#
# gVal:  3
# g cost of  neighborNode:  (0, 1) without adding parent cost is:  3
# g cost of parent node:  (0, 2) is:  7
# g cost of neighborNode:  (0, 1) plus its parentNode's:  (0, 2) g cost is:  10
# (0, 1) not pushed
# Current Node:  (2, 0)
# Unsuccessful goal check number:  6
# Closed Nodes:  {(0, 1), (0, 0), (2, 0), (1, 1), (1, 0), (0, 2)}
#
# Main for-loop iteration:  21
# The currentNode is:  (2, 0)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (2, 1) in iteration:  21
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 1) is on the array
# neighborNode (2, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 1)
# index after cast:  [2, 1]
# Obtain cost of node: [ 2 1 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (2, 1) without adding parent cost is:  9
# g cost of parent node:  (2, 0) is:  7
# g cost of neighborNode:  (2, 1) plus its parentNode's:  (2, 0) g cost is:  16
#
# Main for-loop iteration:  22
# The currentNode is:  (2, 0)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (3, 0) in iteration:  22
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 0) is on the array
# neighborNode (3, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 0)
# index after cast:  [3, 0]
# Obtain cost of node: [ 3 0 ] from numpy array cost matrix
#
#
# gVal:  8
# g cost of  neighborNode:  (3, 0) without adding parent cost is:  8
# g cost of parent node:  (2, 0) is:  7
# g cost of neighborNode:  (3, 0) plus its parentNode's:  (2, 0) g cost is:  15
# (3, 0)  added to open list
# h of neighborNode:  (3, 0) is:  7
# f cost of neighborNode:  (3, 0) is:  22
#
# Main for-loop iteration:  23
# The currentNode is:  (2, 0)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (1, 0) in iteration:  23
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 0) is on the array
# neighborNode (1, 0) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 0)
# index after cast:  [1, 0]
# Obtain cost of node: [ 1 0 ] from numpy array cost matrix
#
#
# gVal:  1
# g cost of  neighborNode:  (1, 0) without adding parent cost is:  1
# g cost of parent node:  (2, 0) is:  7
# g cost of neighborNode:  (1, 0) plus its parentNode's:  (2, 0) g cost is:  8
# (1, 0) not pushed
#
# Main for-loop iteration:  24
# The currentNode is:  (2, 0)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (2, -1) in iteration:  24
# Check 1 passed
# Check 2 passed
# (2, -1) :not on array
# Current Node:  (0, 3)
# Unsuccessful goal check number:  7
# Closed Nodes:  {(0, 1), (0, 0), (2, 0), (1, 1), (1, 0), (0, 2), (0, 3)}
#
# Main for-loop iteration:  25
# The currentNode is:  (0, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (0, 4) in iteration:  25
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 4) is on the array
# neighborNode (0, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 4)
# index after cast:  [0, 4]
# Obtain cost of node: [ 0 4 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (0, 4) without adding parent cost is:  9
# g cost of parent node:  (0, 3) is:  7
# g cost of neighborNode:  (0, 4) plus its parentNode's:  (0, 3) g cost is:  16
# (0, 4)  added to open list
# h of neighborNode:  (0, 4) is:  10
# f cost of neighborNode:  (0, 4) is:  26
#
# Main for-loop iteration:  26
# The currentNode is:  (0, 3)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (1, 3) in iteration:  26
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 3) is on the array
# neighborNode (1, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 3)
# index after cast:  [1, 3]
# Obtain cost of node: [ 1 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (1, 3) without adding parent cost is:  0
# g cost of parent node:  (0, 3) is:  7
# g cost of neighborNode:  (1, 3) plus its parentNode's:  (0, 3) g cost is:  7
# (1, 3)  added to open list
# h of neighborNode:  (1, 3) is:  8
# f cost of neighborNode:  (1, 3) is:  15
#
# Main for-loop iteration:  27
# The currentNode is:  (0, 3)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (-1, 3) in iteration:  27
# (-1, 3) :not on array
#
# Main for-loop iteration:  28
# The currentNode is:  (0, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (0, 2) in iteration:  28
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 2) is on the array
# neighborNode (0, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 2)
# index after cast:  [0, 2]
# Obtain cost of node: [ 0 2 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (0, 2) without adding parent cost is:  4
# g cost of parent node:  (0, 3) is:  7
# g cost of neighborNode:  (0, 2) plus its parentNode's:  (0, 3) g cost is:  11
# (0, 2) not pushed
# Current Node:  (1, 3)
# Unsuccessful goal check number:  8
# Closed Nodes:  {(0, 1), (0, 0), (1, 3), (2, 0), (1, 1), (1, 0), (0, 2), (0, 3)}
#
# Main for-loop iteration:  29
# The currentNode is:  (1, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (1, 4) in iteration:  29
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 4) is on the array
# neighborNode (1, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 4)
# index after cast:  [1, 4]
# Obtain cost of node: [ 1 4 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (1, 4) without adding parent cost is:  2
# g cost of parent node:  (1, 3) is:  7
# g cost of neighborNode:  (1, 4) plus its parentNode's:  (1, 3) g cost is:  9
# (1, 4)  added to open list
# h of neighborNode:  (1, 4) is:  9
# f cost of neighborNode:  (1, 4) is:  18
#
# Main for-loop iteration:  30
# The currentNode is:  (1, 3)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 3) in iteration:  30
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 3) is on the array
# neighborNode (2, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 3)
# index after cast:  [2, 3]
# Obtain cost of node: [ 2 3 ] from numpy array cost matrix
#
#
# gVal:  8
# g cost of  neighborNode:  (2, 3) without adding parent cost is:  8
# g cost of parent node:  (1, 3) is:  7
# g cost of neighborNode:  (2, 3) plus its parentNode's:  (1, 3) g cost is:  15
# (2, 3)  added to open list
# h of neighborNode:  (2, 3) is:  7
# f cost of neighborNode:  (2, 3) is:  22
#
# Main for-loop iteration:  31
# The currentNode is:  (1, 3)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (0, 3) in iteration:  31
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 3) is on the array
# neighborNode (0, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 3)
# index after cast:  [0, 3]
# Obtain cost of node: [ 0 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (0, 3) without adding parent cost is:  0
# g cost of parent node:  (1, 3) is:  7
# g cost of neighborNode:  (0, 3) plus its parentNode's:  (1, 3) g cost is:  7
# (0, 3) not pushed
#
# Main for-loop iteration:  32
# The currentNode is:  (1, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (1, 2) in iteration:  32
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 2) is on the array
# neighborNode (1, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 2)
# index after cast:  [1, 2]
# Obtain cost of node: [ 1 2 ] from numpy array cost matrix
#
#
# gVal:  5
# g cost of  neighborNode:  (1, 2) without adding parent cost is:  5
# g cost of parent node:  (1, 3) is:  7
# g cost of neighborNode:  (1, 2) plus its parentNode's:  (1, 3) g cost is:  12
# Current Node:  (1, 2)
# Unsuccessful goal check number:  9
# Closed Nodes:  {(0, 1), (1, 2), (0, 0), (1, 3), (2, 0), (1, 1), (1, 0), (0, 2), (0, 3)}
#
# Main for-loop iteration:  33
# The currentNode is:  (1, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (1, 3) in iteration:  33
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 3) is on the array
# neighborNode (1, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 3)
# index after cast:  [1, 3]
# Obtain cost of node: [ 1 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (1, 3) without adding parent cost is:  0
# g cost of parent node:  (1, 2) is:  10
# g cost of neighborNode:  (1, 3) plus its parentNode's:  (1, 2) g cost is:  10
# (1, 3) not pushed
#
# Main for-loop iteration:  34
# The currentNode is:  (1, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 2) in iteration:  34
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 2) is on the array
# neighborNode (2, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 2)
# index after cast:  [2, 2]
# Obtain cost of node: [ 2 2 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (2, 2) without adding parent cost is:  9
# g cost of parent node:  (1, 2) is:  10
# g cost of neighborNode:  (2, 2) plus its parentNode's:  (1, 2) g cost is:  19
# (2, 2)  added to open list
# h of neighborNode:  (2, 2) is:  6
# f cost of neighborNode:  (2, 2) is:  25
#
# Main for-loop iteration:  35
# The currentNode is:  (1, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (0, 2) in iteration:  35
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 2) is on the array
# neighborNode (0, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 2)
# index after cast:  [0, 2]
# Obtain cost of node: [ 0 2 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (0, 2) without adding parent cost is:  4
# g cost of parent node:  (1, 2) is:  10
# g cost of neighborNode:  (0, 2) plus its parentNode's:  (1, 2) g cost is:  14
# (0, 2) not pushed
#
# Main for-loop iteration:  36
# The currentNode is:  (1, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (1, 1) in iteration:  36
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 1) is on the array
# neighborNode (1, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 1)
# index after cast:  [1, 1]
# Obtain cost of node: [ 1 1 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (1, 1) without adding parent cost is:  4
# g cost of parent node:  (1, 2) is:  10
# g cost of neighborNode:  (1, 1) plus its parentNode's:  (1, 2) g cost is:  14
# (1, 1) not pushed
# Current Node:  (1, 4)
# Unsuccessful goal check number:  10
# Closed Nodes:  {(0, 1), (1, 2), (0, 0), (1, 3), (1, 4), (2, 0), (1, 1), (1, 0), (0, 2), (0, 3)}
#
# Main for-loop iteration:  37
# The currentNode is:  (1, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (1, 5) in iteration:  37
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 5) is on the array
# neighborNode (1, 5) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 5)
# index after cast:  [1, 5]
# Obtain cost of node: [ 1 5 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (1, 5) without adding parent cost is:  2
# g cost of parent node:  (1, 4) is:  9
# g cost of neighborNode:  (1, 5) plus its parentNode's:  (1, 4) g cost is:  11
# (1, 5)  added to open list
# h of neighborNode:  (1, 5) is:  10
# f cost of neighborNode:  (1, 5) is:  21
#
# Main for-loop iteration:  38
# The currentNode is:  (1, 4)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 4) in iteration:  38
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 4) is on the array
# neighborNode (2, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 4)
# index after cast:  [2, 4]
# Obtain cost of node: [ 2 4 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (2, 4) without adding parent cost is:  0
# g cost of parent node:  (1, 4) is:  9
# g cost of neighborNode:  (2, 4) plus its parentNode's:  (1, 4) g cost is:  9
# (2, 4)  added to open list
# h of neighborNode:  (2, 4) is:  8
# f cost of neighborNode:  (2, 4) is:  17
#
# Main for-loop iteration:  39
# The currentNode is:  (1, 4)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (0, 4) in iteration:  39
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (0, 4) is on the array
# neighborNode (0, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (0, 4)
# index after cast:  [0, 4]
# Obtain cost of node: [ 0 4 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (0, 4) without adding parent cost is:  9
# g cost of parent node:  (1, 4) is:  9
# g cost of neighborNode:  (0, 4) plus its parentNode's:  (1, 4) g cost is:  18
#
# Main for-loop iteration:  40
# The currentNode is:  (1, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (1, 3) in iteration:  40
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 3) is on the array
# neighborNode (1, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 3)
# index after cast:  [1, 3]
# Obtain cost of node: [ 1 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (1, 3) without adding parent cost is:  0
# g cost of parent node:  (1, 4) is:  9
# g cost of neighborNode:  (1, 3) plus its parentNode's:  (1, 4) g cost is:  9
# (1, 3) not pushed
# Current Node:  (2, 4)
# Unsuccessful goal check number:  11
# Closed Nodes:  {(0, 1), (1, 2), (0, 0), (1, 3), (1, 4), (2, 0), (1, 1), (2, 4), (1, 0), (0, 2), (0, 3)}
#
# Main for-loop iteration:  41
# The currentNode is:  (2, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (2, 5) in iteration:  41
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 5) is on the array
# neighborNode (2, 5) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 5)
# index after cast:  [2, 5]
# Obtain cost of node: [ 2 5 ] from numpy array cost matrix
#
#
# gVal:  3
# g cost of  neighborNode:  (2, 5) without adding parent cost is:  3
# g cost of parent node:  (2, 4) is:  9
# g cost of neighborNode:  (2, 5) plus its parentNode's:  (2, 4) g cost is:  12
# (2, 5)  added to open list
# h of neighborNode:  (2, 5) is:  9
# f cost of neighborNode:  (2, 5) is:  21
#
# Main for-loop iteration:  42
# The currentNode is:  (2, 4)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (3, 4) in iteration:  42
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 4) is on the array
# neighborNode (3, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 4)
# index after cast:  [3, 4]
# Obtain cost of node: [ 3 4 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (3, 4) without adding parent cost is:  2
# g cost of parent node:  (2, 4) is:  9
# g cost of neighborNode:  (3, 4) plus its parentNode's:  (2, 4) g cost is:  11
# (3, 4)  added to open list
# h of neighborNode:  (3, 4) is:  7
# f cost of neighborNode:  (3, 4) is:  18
#
# Main for-loop iteration:  43
# The currentNode is:  (2, 4)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (1, 4) in iteration:  43
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 4) is on the array
# neighborNode (1, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 4)
# index after cast:  [1, 4]
# Obtain cost of node: [ 1 4 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (1, 4) without adding parent cost is:  2
# g cost of parent node:  (2, 4) is:  9
# g cost of neighborNode:  (1, 4) plus its parentNode's:  (2, 4) g cost is:  11
# (1, 4) not pushed
#
# Main for-loop iteration:  44
# The currentNode is:  (2, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (2, 3) in iteration:  44
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 3) is on the array
# neighborNode (2, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 3)
# index after cast:  [2, 3]
# Obtain cost of node: [ 2 3 ] from numpy array cost matrix
#
#
# gVal:  8
# g cost of  neighborNode:  (2, 3) without adding parent cost is:  8
# g cost of parent node:  (2, 4) is:  9
# g cost of neighborNode:  (2, 3) plus its parentNode's:  (2, 4) g cost is:  17
# Current Node:  (3, 4)
# Unsuccessful goal check number:  12
# Closed Nodes:  {(0, 1), (1, 2), (0, 0), (1, 3), (1, 4), (2, 0), (1, 1), (2, 4), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  45
# The currentNode is:  (3, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (3, 5) in iteration:  45
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 5) is on the array
# neighborNode (3, 5) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 5)
# index after cast:  [3, 5]
# Obtain cost of node: [ 3 5 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (3, 5) without adding parent cost is:  9
# g cost of parent node:  (3, 4) is:  11
# g cost of neighborNode:  (3, 5) plus its parentNode's:  (3, 4) g cost is:  20
# (3, 5)  added to open list
# h of neighborNode:  (3, 5) is:  8
# f cost of neighborNode:  (3, 5) is:  28
#
# Main for-loop iteration:  46
# The currentNode is:  (3, 4)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (4, 4) in iteration:  46
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 4) is on the array
# neighborNode (4, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 4)
# index after cast:  [4, 4]
# Obtain cost of node: [ 4 4 ] from numpy array cost matrix
#
#
# gVal:  5
# g cost of  neighborNode:  (4, 4) without adding parent cost is:  5
# g cost of parent node:  (3, 4) is:  11
# g cost of neighborNode:  (4, 4) plus its parentNode's:  (3, 4) g cost is:  16
# (4, 4)  added to open list
# h of neighborNode:  (4, 4) is:  6
# f cost of neighborNode:  (4, 4) is:  22
#
# Main for-loop iteration:  47
# The currentNode is:  (3, 4)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 4) in iteration:  47
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 4) is on the array
# neighborNode (2, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 4)
# index after cast:  [2, 4]
# Obtain cost of node: [ 2 4 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (2, 4) without adding parent cost is:  0
# g cost of parent node:  (3, 4) is:  11
# g cost of neighborNode:  (2, 4) plus its parentNode's:  (3, 4) g cost is:  11
# (2, 4) not pushed
#
# Main for-loop iteration:  48
# The currentNode is:  (3, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (3, 3) in iteration:  48
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 3) is on the array
# neighborNode (3, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 3)
# index after cast:  [3, 3]
# Obtain cost of node: [ 3 3 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (3, 3) without adding parent cost is:  2
# g cost of parent node:  (3, 4) is:  11
# g cost of neighborNode:  (3, 3) plus its parentNode's:  (3, 4) g cost is:  13
# (3, 3)  added to open list
# h of neighborNode:  (3, 3) is:  6
# f cost of neighborNode:  (3, 3) is:  19
# Current Node:  (3, 3)
# Unsuccessful goal check number:  13
# Closed Nodes:  {(0, 1), (1, 2), (0, 0), (1, 3), (3, 3), (1, 4), (2, 0), (1, 1), (2, 4), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  49
# The currentNode is:  (3, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (3, 4) in iteration:  49
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 4) is on the array
# neighborNode (3, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 4)
# index after cast:  [3, 4]
# Obtain cost of node: [ 3 4 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (3, 4) without adding parent cost is:  2
# g cost of parent node:  (3, 3) is:  13
# g cost of neighborNode:  (3, 4) plus its parentNode's:  (3, 3) g cost is:  15
# (3, 4) not pushed
#
# Main for-loop iteration:  50
# The currentNode is:  (3, 3)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (4, 3) in iteration:  50
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 3) is on the array
# neighborNode (4, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 3)
# index after cast:  [4, 3]
# Obtain cost of node: [ 4 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (4, 3) without adding parent cost is:  7
# g cost of parent node:  (3, 3) is:  13
# g cost of neighborNode:  (4, 3) plus its parentNode's:  (3, 3) g cost is:  20
# (4, 3)  added to open list
# h of neighborNode:  (4, 3) is:  5
# f cost of neighborNode:  (4, 3) is:  25
#
# Main for-loop iteration:  51
# The currentNode is:  (3, 3)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 3) in iteration:  51
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 3) is on the array
# neighborNode (2, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 3)
# index after cast:  [2, 3]
# Obtain cost of node: [ 2 3 ] from numpy array cost matrix
#
#
# gVal:  8
# g cost of  neighborNode:  (2, 3) without adding parent cost is:  8
# g cost of parent node:  (3, 3) is:  13
# g cost of neighborNode:  (2, 3) plus its parentNode's:  (3, 3) g cost is:  21
#
# Main for-loop iteration:  52
# The currentNode is:  (3, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (3, 2) in iteration:  52
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 2) is on the array
# neighborNode (3, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 2)
# index after cast:  [3, 2]
# Obtain cost of node: [ 3 2 ] from numpy array cost matrix
#
#
# gVal:  1
# g cost of  neighborNode:  (3, 2) without adding parent cost is:  1
# g cost of parent node:  (3, 3) is:  13
# g cost of neighborNode:  (3, 2) plus its parentNode's:  (3, 3) g cost is:  14
# (3, 2)  added to open list
# h of neighborNode:  (3, 2) is:  5
# f cost of neighborNode:  (3, 2) is:  19
# Current Node:  (3, 2)
# Unsuccessful goal check number:  14
# Closed Nodes:  {(0, 1), (1, 2), (3, 2), (0, 0), (1, 3), (3, 3), (1, 4), (2, 0), (1, 1), (2, 4), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  53
# The currentNode is:  (3, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (3, 3) in iteration:  53
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 3) is on the array
# neighborNode (3, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 3)
# index after cast:  [3, 3]
# Obtain cost of node: [ 3 3 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (3, 3) without adding parent cost is:  2
# g cost of parent node:  (3, 2) is:  14
# g cost of neighborNode:  (3, 3) plus its parentNode's:  (3, 2) g cost is:  16
# (3, 3) not pushed
#
# Main for-loop iteration:  54
# The currentNode is:  (3, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (4, 2) in iteration:  54
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 2) is on the array
# neighborNode (4, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 2)
# index after cast:  [4, 2]
# Obtain cost of node: [ 4 2 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (4, 2) without adding parent cost is:  2
# g cost of parent node:  (3, 2) is:  14
# g cost of neighborNode:  (4, 2) plus its parentNode's:  (3, 2) g cost is:  16
# (4, 2)  added to open list
# h of neighborNode:  (4, 2) is:  4
# f cost of neighborNode:  (4, 2) is:  20
#
# Main for-loop iteration:  55
# The currentNode is:  (3, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 2) in iteration:  55
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 2) is on the array
# neighborNode (2, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 2)
# index after cast:  [2, 2]
# Obtain cost of node: [ 2 2 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (2, 2) without adding parent cost is:  9
# g cost of parent node:  (3, 2) is:  14
# g cost of neighborNode:  (2, 2) plus its parentNode's:  (3, 2) g cost is:  23
#
# Main for-loop iteration:  56
# The currentNode is:  (3, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (3, 1) in iteration:  56
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 1) is on the array
# neighborNode (3, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 1)
# index after cast:  [3, 1]
# Obtain cost of node: [ 3 1 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (3, 1) without adding parent cost is:  9
# g cost of parent node:  (3, 2) is:  14
# g cost of neighborNode:  (3, 1) plus its parentNode's:  (3, 2) g cost is:  23
# (3, 1)  added to open list
# h of neighborNode:  (3, 1) is:  6
# f cost of neighborNode:  (3, 1) is:  29
# Current Node:  (4, 2)
# Unsuccessful goal check number:  15
# Closed Nodes:  {(0, 1), (1, 2), (3, 2), (0, 0), (1, 3), (3, 3), (1, 4), (2, 0), (1, 1), (2, 4), (4, 2), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  57
# The currentNode is:  (4, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (4, 3) in iteration:  57
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 3) is on the array
# neighborNode (4, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 3)
# index after cast:  [4, 3]
# Obtain cost of node: [ 4 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (4, 3) without adding parent cost is:  7
# g cost of parent node:  (4, 2) is:  16
# g cost of neighborNode:  (4, 3) plus its parentNode's:  (4, 2) g cost is:  23
#
# Main for-loop iteration:  58
# The currentNode is:  (4, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (5, 2) in iteration:  58
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 2) is on the array
# neighborNode (5, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 2)
# index after cast:  [5, 2]
# Obtain cost of node: [ 5 2 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (5, 2) without adding parent cost is:  0
# g cost of parent node:  (4, 2) is:  16
# g cost of neighborNode:  (5, 2) plus its parentNode's:  (4, 2) g cost is:  16
# (5, 2)  added to open list
# h of neighborNode:  (5, 2) is:  3
# f cost of neighborNode:  (5, 2) is:  19
#
# Main for-loop iteration:  59
# The currentNode is:  (4, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (3, 2) in iteration:  59
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (3, 2) is on the array
# neighborNode (3, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (3, 2)
# index after cast:  [3, 2]
# Obtain cost of node: [ 3 2 ] from numpy array cost matrix
#
#
# gVal:  1
# g cost of  neighborNode:  (3, 2) without adding parent cost is:  1
# g cost of parent node:  (4, 2) is:  16
# g cost of neighborNode:  (3, 2) plus its parentNode's:  (4, 2) g cost is:  17
# (3, 2) not pushed
#
# Main for-loop iteration:  60
# The currentNode is:  (4, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (4, 1) in iteration:  60
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 1) is on the array
# neighborNode (4, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 1)
# index after cast:  [4, 1]
# Obtain cost of node: [ 4 1 ] from numpy array cost matrix
#
#
# gVal:  5
# g cost of  neighborNode:  (4, 1) without adding parent cost is:  5
# g cost of parent node:  (4, 2) is:  16
# g cost of neighborNode:  (4, 1) plus its parentNode's:  (4, 2) g cost is:  21
# (4, 1)  added to open list
# h of neighborNode:  (4, 1) is:  5
# f cost of neighborNode:  (4, 1) is:  26
# Current Node:  (5, 2)
# Unsuccessful goal check number:  16
# Closed Nodes:  {(0, 1), (1, 2), (3, 2), (0, 0), (1, 3), (3, 3), (5, 2), (1, 4), (2, 0), (1, 1), (2, 4), (4, 2), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  61
# The currentNode is:  (5, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (5, 3) in iteration:  61
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 3) is on the array
# neighborNode (5, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 3)
# index after cast:  [5, 3]
# Obtain cost of node: [ 5 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (5, 3) without adding parent cost is:  7
# g cost of parent node:  (5, 2) is:  16
# g cost of neighborNode:  (5, 3) plus its parentNode's:  (5, 2) g cost is:  23
# (5, 3)  added to open list
# h of neighborNode:  (5, 3) is:  4
# f cost of neighborNode:  (5, 3) is:  27
#
# Main for-loop iteration:  62
# The currentNode is:  (5, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (6, 2) in iteration:  62
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 2) is on the array
# neighborNode (6, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 2)
# index after cast:  [6, 2]
# Obtain cost of node: [ 6 2 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (6, 2) without adding parent cost is:  0
# g cost of parent node:  (5, 2) is:  16
# g cost of neighborNode:  (6, 2) plus its parentNode's:  (5, 2) g cost is:  16
# (6, 2)  added to open list
# h of neighborNode:  (6, 2) is:  2
# f cost of neighborNode:  (6, 2) is:  18
#
# Main for-loop iteration:  63
# The currentNode is:  (5, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (4, 2) in iteration:  63
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 2) is on the array
# neighborNode (4, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 2)
# index after cast:  [4, 2]
# Obtain cost of node: [ 4 2 ] from numpy array cost matrix
#
#
# gVal:  2
# g cost of  neighborNode:  (4, 2) without adding parent cost is:  2
# g cost of parent node:  (5, 2) is:  16
# g cost of neighborNode:  (4, 2) plus its parentNode's:  (5, 2) g cost is:  18
# (4, 2) not pushed
#
# Main for-loop iteration:  64
# The currentNode is:  (5, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (5, 1) in iteration:  64
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 1) is on the array
# neighborNode (5, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 1)
# index after cast:  [5, 1]
# Obtain cost of node: [ 5 1 ] from numpy array cost matrix
#
#
# gVal:  6
# g cost of  neighborNode:  (5, 1) without adding parent cost is:  6
# g cost of parent node:  (5, 2) is:  16
# g cost of neighborNode:  (5, 1) plus its parentNode's:  (5, 2) g cost is:  22
# (5, 1)  added to open list
# h of neighborNode:  (5, 1) is:  4
# f cost of neighborNode:  (5, 1) is:  26
# Current Node:  (6, 2)
# Unsuccessful goal check number:  17
# Closed Nodes:  {(0, 1), (1, 2), (3, 2), (0, 0), (1, 3), (3, 3), (5, 2), (1, 4), (2, 0), (1, 1), (6, 2), (2, 4), (4, 2), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  65
# The currentNode is:  (6, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (6, 3) in iteration:  65
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 3) is on the array
# neighborNode (6, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 3)
# index after cast:  [6, 3]
# Obtain cost of node: [ 6 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (6, 3) without adding parent cost is:  7
# g cost of parent node:  (6, 2) is:  16
# g cost of neighborNode:  (6, 3) plus its parentNode's:  (6, 2) g cost is:  23
# (6, 3)  added to open list
# h of neighborNode:  (6, 3) is:  3
# f cost of neighborNode:  (6, 3) is:  26
#
# Main for-loop iteration:  66
# The currentNode is:  (6, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (7, 2) in iteration:  66
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (7, 2) is on the array
# neighborNode (7, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (7, 2)
# index after cast:  [7, 2]
# Obtain cost of node: [ 7 2 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (7, 2) without adding parent cost is:  9
# g cost of parent node:  (6, 2) is:  16
# g cost of neighborNode:  (7, 2) plus its parentNode's:  (6, 2) g cost is:  25
# (7, 2)  added to open list
# h of neighborNode:  (7, 2) is:  1
# f cost of neighborNode:  (7, 2) is:  26
#
# Main for-loop iteration:  67
# The currentNode is:  (6, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (5, 2) in iteration:  67
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 2) is on the array
# neighborNode (5, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 2)
# index after cast:  [5, 2]
# Obtain cost of node: [ 5 2 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (5, 2) without adding parent cost is:  0
# g cost of parent node:  (6, 2) is:  16
# g cost of neighborNode:  (5, 2) plus its parentNode's:  (6, 2) g cost is:  16
# (5, 2) not pushed
#
# Main for-loop iteration:  68
# The currentNode is:  (6, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (6, 1) in iteration:  68
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 1) is on the array
# neighborNode (6, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 1)
# index after cast:  [6, 1]
# Obtain cost of node: [ 6 1 ] from numpy array cost matrix
#
#
# gVal:  8
# g cost of  neighborNode:  (6, 1) without adding parent cost is:  8
# g cost of parent node:  (6, 2) is:  16
# g cost of neighborNode:  (6, 1) plus its parentNode's:  (6, 2) g cost is:  24
# (6, 1)  added to open list
# h of neighborNode:  (6, 1) is:  3
# f cost of neighborNode:  (6, 1) is:  27
# Current Node:  (1, 5)
# Unsuccessful goal check number:  18
# Closed Nodes:  {(0, 1), (1, 2), (3, 2), (0, 0), (1, 3), (3, 3), (5, 2), (1, 4), (2, 0), (1, 5), (1, 1), (6, 2), (2, 4), (4, 2), (1, 0), (3, 4), (0, 2), (0, 3)}
#
# Main for-loop iteration:  69
# The currentNode is:  (1, 5)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (1, 6) in iteration:  69
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (1, 6) is on the array
# neighborNode (1, 6) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (1, 6)
# index after cast:  [1, 6]
# Obtain cost of node: [ 1 6 ] from numpy array cost matrix
#
#
# gVal:  3
# g cost of  neighborNode:  (1, 6) without adding parent cost is:  3
# g cost of parent node:  (1, 5) is:  11
# g cost of neighborNode:  (1, 6) plus its parentNode's:  (1, 5) g cost is:  14
# (1, 6)  added to open list
# h of neighborNode:  (1, 6) is:  11
# f cost of neighborNode:  (1, 6) is:  25
#
# Main for-loop iteration:  70
# The currentNode is:  (1, 5)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (2, 5) in iteration:  70
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (2, 5) is on the array
# neighborNode (2, 5) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (2, 5)
# index after cast:  [2, 5]
# Obtain cost of node: [ 2 5 ] from numpy array cost matrix
#
#
# gVal:  3
# g cost of  neighborNode:  (2, 5) without adding parent cost is:  3
# g cost of parent node:  (1, 5) is:  11
# g cost of neighborNode:  (2, 5) plus its parentNode's:  (1, 5) g cost is:  14
#
# Main for-loop iteration:  71
# The currentNode is:  (1, 5)
# [0] value in adjacentNode list:  -1
# ...
#
# Main for-loop iteration:  141
# The currentNode is:  (5, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (5, 5) in iteration:  141
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 5) is on the array
# neighborNode (5, 5) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 5)
# index after cast:  [5, 5]
# Obtain cost of node: [ 5 5 ] from numpy array cost matrix
#
#
# gVal:  1
# g cost of  neighborNode:  (5, 5) without adding parent cost is:  1
# g cost of parent node:  (5, 4) is:  21
# g cost of neighborNode:  (5, 5) plus its parentNode's:  (5, 4) g cost is:  22
# (5, 5) not pushed
#
# Main for-loop iteration:  142
# The currentNode is:  (5, 4)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (6, 4) in iteration:  142
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 4) is on the array
# neighborNode (6, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 4)
# index after cast:  [6, 4]
# Obtain cost of node: [ 6 4 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (6, 4) without adding parent cost is:  7
# g cost of parent node:  (5, 4) is:  21
# g cost of neighborNode:  (6, 4) plus its parentNode's:  (5, 4) g cost is:  28
#
# Main for-loop iteration:  143
# The currentNode is:  (5, 4)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (4, 4) in iteration:  143
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (4, 4) is on the array
# neighborNode (4, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (4, 4)
# index after cast:  [4, 4]
# Obtain cost of node: [ 4 4 ] from numpy array cost matrix
#
#
# gVal:  5
# g cost of  neighborNode:  (4, 4) without adding parent cost is:  5
# g cost of parent node:  (5, 4) is:  21
# g cost of neighborNode:  (4, 4) plus its parentNode's:  (5, 4) g cost is:  26
# (4, 4) not pushed
#
# Main for-loop iteration:  144
# The currentNode is:  (5, 4)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (5, 3) in iteration:  144
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 3) is on the array
# neighborNode (5, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 3)
# index after cast:  [5, 3]
# Obtain cost of node: [ 5 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (5, 3) without adding parent cost is:  7
# g cost of parent node:  (5, 4) is:  21
# g cost of neighborNode:  (5, 3) plus its parentNode's:  (5, 4) g cost is:  28
# Current Node:  (6, 3)
# Unsuccessful goal check number:  37
# Closed Nodes:  {(1, 3), (3, 0), (0, 2), (2, 1), (6, 2), (1, 6), (5, 1), (2, 5), (0, 3), (4, 0), (1, 2), (3, 3), (5, 5), (4, 4), (6, 3), (1, 5), (2, 2), (3, 4), (0, 4), (4, 1), (1, 1), (3, 2), (0, 0), (5, 4), (4, 5), (1, 4), (2, 3), (0, 5), (4, 2), (1, 0), (6, 5), (0, 1), (4, 6), (2, 0), (4, 3), (5, 2), (2, 4)}
#
# Main for-loop iteration:  145
# The currentNode is:  (6, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (6, 4) in iteration:  145
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 4) is on the array
# neighborNode (6, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 4)
# index after cast:  [6, 4]
# Obtain cost of node: [ 6 4 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (6, 4) without adding parent cost is:  7
# g cost of parent node:  (6, 3) is:  23
# g cost of neighborNode:  (6, 4) plus its parentNode's:  (6, 3) g cost is:  30
#
# Main for-loop iteration:  146
# The currentNode is:  (6, 3)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (7, 3) in iteration:  146
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (7, 3) is on the array
# neighborNode (7, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (7, 3)
# index after cast:  [7, 3]
# Obtain cost of node: [ 7 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (7, 3) without adding parent cost is:  0
# g cost of parent node:  (6, 3) is:  23
# g cost of neighborNode:  (7, 3) plus its parentNode's:  (6, 3) g cost is:  23
# (7, 3)  added to open list
# h of neighborNode:  (7, 3) is:  2
# f cost of neighborNode:  (7, 3) is:  25
#
# Main for-loop iteration:  147
# The currentNode is:  (6, 3)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (5, 3) in iteration:  147
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (5, 3) is on the array
# neighborNode (5, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (5, 3)
# index after cast:  [5, 3]
# Obtain cost of node: [ 5 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (5, 3) without adding parent cost is:  7
# g cost of parent node:  (6, 3) is:  23
# g cost of neighborNode:  (5, 3) plus its parentNode's:  (6, 3) g cost is:  30
#
# Main for-loop iteration:  148
# The currentNode is:  (6, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (6, 2) in iteration:  148
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 2) is on the array
# neighborNode (6, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 2)
# index after cast:  [6, 2]
# Obtain cost of node: [ 6 2 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (6, 2) without adding parent cost is:  0
# g cost of parent node:  (6, 3) is:  23
# g cost of neighborNode:  (6, 2) plus its parentNode's:  (6, 3) g cost is:  23
# (6, 2) not pushed
# Current Node:  (7, 3)
# Unsuccessful goal check number:  38
# Closed Nodes:  {(7, 3), (1, 3), (3, 0), (0, 2), (2, 1), (6, 2), (1, 6), (5, 1), (2, 5), (0, 3), (4, 0), (1, 2), (3, 3), (5, 5), (4, 4), (6, 3), (1, 5), (2, 2), (3, 4), (0, 4), (4, 1), (1, 1), (3, 2), (0, 0), (5, 4), (4, 5), (1, 4), (2, 3), (0, 5), (4, 2), (1, 0), (6, 5), (0, 1), (4, 6), (2, 0), (4, 3), (5, 2), (2, 4)}
#
# Main for-loop iteration:  149
# The currentNode is:  (7, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (7, 4) in iteration:  149
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (7, 4) is on the array
# neighborNode (7, 4) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (7, 4)
# index after cast:  [7, 4]
# Obtain cost of node: [ 7 4 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (7, 4) without adding parent cost is:  7
# g cost of parent node:  (7, 3) is:  23
# g cost of neighborNode:  (7, 4) plus its parentNode's:  (7, 3) g cost is:  30
# (7, 4)  added to open list
# h of neighborNode:  (7, 4) is:  3
# f cost of neighborNode:  (7, 4) is:  33
#
# Main for-loop iteration:  150
# The currentNode is:  (7, 3)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (8, 3) in iteration:  150
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (8, 3) is on the array
# neighborNode (8, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (8, 3)
# index after cast:  [8, 3]
# Obtain cost of node: [ 8 3 ] from numpy array cost matrix
#
#
# gVal:  4
# g cost of  neighborNode:  (8, 3) without adding parent cost is:  4
# g cost of parent node:  (7, 3) is:  23
# g cost of neighborNode:  (8, 3) plus its parentNode's:  (7, 3) g cost is:  27
# (8, 3)  added to open list
# h of neighborNode:  (8, 3) is:  1
# f cost of neighborNode:  (8, 3) is:  28
#
# Main for-loop iteration:  151
# The currentNode is:  (7, 3)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (6, 3) in iteration:  151
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 3) is on the array
# neighborNode (6, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 3)
# index after cast:  [6, 3]
# Obtain cost of node: [ 6 3 ] from numpy array cost matrix
#
#
# gVal:  7
# g cost of  neighborNode:  (6, 3) without adding parent cost is:  7
# g cost of parent node:  (7, 3) is:  23
# g cost of neighborNode:  (6, 3) plus its parentNode's:  (7, 3) g cost is:  30
# (6, 3) not pushed
#
# Main for-loop iteration:  152
# The currentNode is:  (7, 3)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (7, 2) in iteration:  152
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (7, 2) is on the array
# neighborNode (7, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (7, 2)
# index after cast:  [7, 2]
# Obtain cost of node: [ 7 2 ] from numpy array cost matrix
#
#
# gVal:  9
# g cost of  neighborNode:  (7, 2) without adding parent cost is:  9
# g cost of parent node:  (7, 3) is:  23
# g cost of neighborNode:  (7, 2) plus its parentNode's:  (7, 3) g cost is:  32
# Current Node:  (7, 2)
# Unsuccessful goal check number:  39
# Closed Nodes:  {(7, 3), (1, 3), (3, 0), (0, 2), (2, 1), (6, 2), (1, 6), (5, 1), (2, 5), (0, 3), (7, 2), (4, 0), (1, 2), (3, 3), (5, 5), (4, 4), (6, 3), (1, 5), (2, 2), (3, 4), (0, 4), (4, 1), (1, 1), (3, 2), (0, 0), (5, 4), (4, 5), (1, 4), (2, 3), (0, 5), (4, 2), (1, 0), (6, 5), (0, 1), (4, 6), (2, 0), (4, 3), (5, 2), (2, 4)}
#
# Main for-loop iteration:  153
# The currentNode is:  (7, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : 1
# This is checkNode:  (7, 3) in iteration:  153
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (7, 3) is on the array
# neighborNode (7, 3) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (7, 3)
# index after cast:  [7, 3]
# Obtain cost of node: [ 7 3 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (7, 3) without adding parent cost is:  0
# g cost of parent node:  (7, 2) is:  25
# g cost of neighborNode:  (7, 3) plus its parentNode's:  (7, 2) g cost is:  25
# (7, 3) not pushed
#
# Main for-loop iteration:  154
# The currentNode is:  (7, 2)
# [0] value in adjacentNode list:  1
# [1] value in adjacentnode list : 0
# This is checkNode:  (8, 2) in iteration:  154
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (8, 2) is on the array
# neighborNode (8, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (8, 2)
# index after cast:  [8, 2]
# Obtain cost of node: [ 8 2 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (8, 2) without adding parent cost is:  0
# g cost of parent node:  (7, 2) is:  25
# g cost of neighborNode:  (8, 2) plus its parentNode's:  (7, 2) g cost is:  25
# (8, 2)  added to open list
# h of neighborNode:  (8, 2) is:  0
# f cost of neighborNode:  (8, 2) is:  25
#
# Main for-loop iteration:  155
# The currentNode is:  (7, 2)
# [0] value in adjacentNode list:  -1
# [1] value in adjacentnode list : 0
# This is checkNode:  (6, 2) in iteration:  155
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (6, 2) is on the array
# neighborNode (6, 2) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (6, 2)
# index after cast:  [6, 2]
# Obtain cost of node: [ 6 2 ] from numpy array cost matrix
#
#
# gVal:  0
# g cost of  neighborNode:  (6, 2) without adding parent cost is:  0
# g cost of parent node:  (7, 2) is:  25
# g cost of neighborNode:  (6, 2) plus its parentNode's:  (7, 2) g cost is:  25
# (6, 2) not pushed
#
# Main for-loop iteration:  156
# The currentNode is:  (7, 2)
# [0] value in adjacentNode list:  0
# [1] value in adjacentnode list : -1
# This is checkNode:  (7, 1) in iteration:  156
# Check 1 passed
# Check 2 passed
# Check 3 passed
# checkNode:  (7, 1) is on the array
# neighborNode (7, 1) has taken the value of checkNode
#
# function call to cost evaluation:
# index:  (7, 1)
# index after cast:  [7, 1]
# Obtain cost of node: [ 7 1 ] from numpy array cost matrix
#
#
# gVal:  8
# g cost of  neighborNode:  (7, 1) without adding parent cost is:  8
# g cost of parent node:  (7, 2) is:  25
# g cost of neighborNode:  (7, 1) plus its parentNode's:  (7, 2) g cost is:  33
# (7, 1)  added to open list
# h of neighborNode:  (7, 1) is:  2
# f cost of neighborNode:  (7, 1) is:  35
# Current Node:  (8, 2)
# Goal has been reached
#
# function call to cost evaluation:
# index:  (8, 2)
# index after cast:  [8, 2]
# Obtain cost of node: [ 8 2 ] from numpy array cost matrix
#
#
# gVal:  0
# (8, 2)  g is cost of current node:  0 , + cost of parent node,total is:  25  h cost is:  0  and f cost is:  25
#
# function call to cost evaluation:
# index:  (7, 2)
# index after cast:  [7, 2]
# Obtain cost of node: [ 7 2 ] from numpy array cost matrix
#
#
# gVal:  9
# (7, 2)  g is cost of current node:  9 , + cost of parent node,total is:  25  h cost is:  1  and f cost is:  26
#
# function call to cost evaluation:
# index:  (6, 2)
# index after cast:  [6, 2]
# Obtain cost of node: [ 6 2 ] from numpy array cost matrix
#
#
# gVal:  0
# (6, 2)  g is cost of current node:  0 , + cost of parent node,total is:  16  h cost is:  2  and f cost is:  18
#
# function call to cost evaluation:
# index:  (5, 2)
# index after cast:  [5, 2]
# Obtain cost of node: [ 5 2 ] from numpy array cost matrix
#
#
# gVal:  0
# (5, 2)  g is cost of current node:  0 , + cost of parent node,total is:  16  h cost is:  3  and f cost is:  19
#
# function call to cost evaluation:
# index:  (4, 2)
# index after cast:  [4, 2]
# Obtain cost of node: [ 4 2 ] from numpy array cost matrix
#
#
# gVal:  2
# (4, 2)  g is cost of current node:  2 , + cost of parent node,total is:  16  h cost is:  4  and f cost is:  20
#
# function call to cost evaluation:
# index:  (3, 2)
# index after cast:  [3, 2]
# Obtain cost of node: [ 3 2 ] from numpy array cost matrix
#
#
# gVal:  1
# (3, 2)  g is cost of current node:  1 , + cost of parent node,total is:  14  h cost is:  5  and f cost is:  19
#
# function call to cost evaluation:
# index:  (3, 3)
# index after cast:  [3, 3]
# Obtain cost of node: [ 3 3 ] from numpy array cost matrix
#
#
# gVal:  2
# (3, 3)  g is cost of current node:  2 , + cost of parent node,total is:  13  h cost is:  6  and f cost is:  19
#
# function call to cost evaluation:
# index:  (3, 4)
# index after cast:  [3, 4]
# Obtain cost of node: [ 3 4 ] from numpy array cost matrix
#
#
# gVal:  2
# (3, 4)  g is cost of current node:  2 , + cost of parent node,total is:  11  h cost is:  7  and f cost is:  18
#
# function call to cost evaluation:
# index:  (2, 4)
# index after cast:  [2, 4]
# Obtain cost of node: [ 2 4 ] from numpy array cost matrix
#
#
# gVal:  0
# (2, 4)  g is cost of current node:  0 , + cost of parent node,total is:  9  h cost is:  8  and f cost is:  17
#
# function call to cost evaluation:
# index:  (1, 4)
# index after cast:  [1, 4]
# Obtain cost of node: [ 1 4 ] from numpy array cost matrix
#
#
# gVal:  2
# (1, 4)  g is cost of current node:  2 , + cost of parent node,total is:  9  h cost is:  9  and f cost is:  18
#
# function call to cost evaluation:
# index:  (1, 3)
# index after cast:  [1, 3]
# Obtain cost of node: [ 1 3 ] from numpy array cost matrix
#
#
# gVal:  0
# (1, 3)  g is cost of current node:  0 , + cost of parent node,total is:  7  h cost is:  8  and f cost is:  15
#
# function call to cost evaluation:
# index:  (0, 3)
# index after cast:  [0, 3]
# Obtain cost of node: [ 0 3 ] from numpy array cost matrix
#
#
# gVal:  0
# (0, 3)  g is cost of current node:  0 , + cost of parent node,total is:  7  h cost is:  9  and f cost is:  16
#
# function call to cost evaluation:
# index:  (0, 2)
# index after cast:  [0, 2]
# Obtain cost of node: [ 0 2 ] from numpy array cost matrix
#
#
# gVal:  4
# (0, 2)  g is cost of current node:  4 , + cost of parent node,total is:  7  h cost is:  8  and f cost is:  15
#
# function call to cost evaluation:
# index:  (0, 1)
# index after cast:  [0, 1]
# Obtain cost of node: [ 0 1 ] from numpy array cost matrix
#
#
# gVal:  3
# (0, 1)  g is cost of current node:  3 , + cost of parent node,total is:  3  h cost is:  9  and f cost is:  12
# Path to goal is:  [(0, 1), (0, 2), (0, 3), (1, 3), (1, 4), (2, 4), (3, 4), (3, 3), (3, 2), (4, 2), (5, 2), (6, 2), (7, 2), (8, 2)]
# [(0, 1),
#  (0, 2),
#  (0, 3),
#  (1, 3),
#  (1, 4),
#  (2, 4),
#  (3, 4),
#  (3, 3),
#  (3, 2),
#  (4, 2),
#  (5, 2),
#  (6, 2),
#  (7, 2),
#  (8, 2)]
